# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %matplotlib inline

# %%
postulantes_genero_edad = pd.read_csv('~/Descargas/Organizacion de Datos/datos_navent_fiuba/fiuba_2_postulantes_genero_y_edad.csv')
postulantes_genero_edad.head(5)
# Out:
#   idpostulante fechanacimiento  sexo
# 0         NM5M      1970-12-03   FEM
# 1         5awk      1962-12-04   FEM
# 2         ZaO5      1978-08-10   FEM
# 3         NdJl      1969-05-09  MASC
# 4         eo2p      1981-02-16  MASC

# %%
postulantes_educacion = pd.read_csv('~/Descargas/Organizacion de Datos/datos_navent_fiuba/fiuba_1_postulantes_educacion.csv')
postulantes_educacion.head(5)
# Out:
#   idpostulante         nombre    estado
# 0         NdJl       Posgrado  En Curso
# 1         8BkL  Universitario  En Curso
# 2         1d2B  Universitario  En Curso
# 3         NPBx  Universitario  En Curso
# 4         NPBx         Master  En Curso

# %%
postulaciones = pd.read_csv('~/Descargas/Organizacion de Datos/datos_navent_fiuba/fiuba_4_postulaciones.csv')
postulaciones.head(5)
# Out:
#       idaviso idpostulante     fechapostulacion
# 0  1112257047         NM5M  2018-01-15 16:22:34
# 1  1111920714         NM5M  2018-02-06 09:04:50
# 2  1112346945         NM5M  2018-02-22 09:04:47
# 3  1112345547         NM5M  2018-02-22 09:04:59
# 4  1112237522         5awk  2018-01-25 18:55:03

# %%
vistas = pd.read_csv('~/Descargas/Organizacion de Datos/datos_navent_fiuba/fiuba_3_vistas.csv')
vistas.head(5)
# Out:
#       idAviso                     timestamp idpostulante
# 0  1111780242  2018-02-23T13:38:13.187-0500      YjVJQ6Z
# 1  1112263876  2018-02-23T13:38:14.296-0500      BmVpYoR
# 2  1112327963  2018-02-23T13:38:14.329-0500      wVkBzZd
# 3  1112318643  2018-02-23T13:38:17.921-0500      OqmP9pv
# 4  1111903673  2018-02-23T13:38:18.973-0500      DrpbXDP

# %%
avisos_online = pd.read_csv('~/Descargas/Organizacion de Datos/datos_navent_fiuba/fiuba_5_avisos_online.csv')
avisos_online.head(5)
# Out:
#       idaviso
# 0  1112355872
# 1  1112335374
# 2  1112374842
# 3  1111984070
# 4  1111822480

# %%
avisos_detalle = pd.read_csv('~/Descargas/Organizacion de Datos/datos_navent_fiuba/fiuba_6_avisos_detalle.csv')
avisos_detalle.head(5)
# Out:
#       idaviso  idpais                                         titulo  \
# 0     8725750       1               VENDEDOR/A PROVINCIA DE SANTA FE
# 1    17903700       1                                     Enfermeras
# 2  1000150677       1                                 Chofer de taxi
# 3  1000610287       1  CHOFER DE CAMIONETA BAHIA BLANCA - PUNTA ALTA
# 4  1000872556       1  Operarios de Planta - Rubro Electrodomésticos
#
#                                          descripcion        nombre_zona  \
# 0  <p><strong><strong>Empresa:</strong></strong> ...  Gran Buenos Aires
# 1  <p>Solicitamos para importante cadena de farma...  Gran Buenos Aires
# 2  <p>TE GUSTA MANEJAR? QUERES GANAR PLATA HACIEN...    Capital Federal
# 3  <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 4  <p><strong>OPERARIOS DE PLANTA</strong></p><p>...  Gran Buenos Aires
#
#   ciudad       mapacalle tipo_de_trabajo         nivel_laboral nombre_area  \
# ...

# %%
postulantes_genero_edad.size
# Out:
# 602664

# %%
postulantes_genero_edad.count
# Out:
# <bound method DataFrame.count of        idpostulante fechanacimiento        sexo
# 0              NM5M      1970-12-03         FEM
# 1              5awk      1962-12-04         FEM
# 2              ZaO5      1978-08-10         FEM
# 3              NdJl      1969-05-09        MASC
# 4              eo2p      1981-02-16        MASC
# 5              Ez8J      1968-12-18        MASC
# 6              aOQq      1966-07-16        MASC
# 7              8BkL      1976-07-21         FEM
# 8              1d2B      1976-02-28        MASC
# 9              NPBx      1981-03-09        MASC
# 10             NRE5      1973-02-13        MASC
# 11             YGBY      1963-04-09         FEM
# 12             6aGl      1967-01-30         FEM
# 13             EbVz      1977-07-16        MASC
# 14             EBO0      1973-09-11         FEM
# 15             10bb      1954-08-30        MASC
# 16             eWO2      1959-01-05        MASC
# 17             6Kbl      1976-09-03        MASC
# ...

# %%
plt.style.use('default')

print(avisos_detalle.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-57633cfa089b> in <module>()
#       1
# ----> 2 plt.style.use('default')
#       3
#       4 print(avisos_detalle.shape)
#
# NameError: name 'plt' is not defined
